# %%
import pandas as pd
data = pd.read_csv('C:/Users/sixxio/Downloads/eighthr.csv')
#data.head(n=100)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
temp = data.columns
tempi = data.index
tempd = data['Date']
data = data.replace('?', np.nan).drop('Date', axis=1)
imp_mean = SimpleImputer()
imp_mean.fit(data)
data = pd.concat(tempd,pd.DataFrame(imp_mean.transform(data)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sixxio\Desktop\ds\other\emil.ipynb Ячейка 2 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/sixxio/Desktop/ds/other/emil.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> imp_mean = SimpleImputer()
#       <a href='vscode-notebook-cell:/c%3A/Users/sixxio/Desktop/ds/other/emil.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> imp_mean.fit(data)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sixxio/Desktop/ds/other/emil.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> data = pd.concat(tempd.to_hdf(),pd.DataFrame(imp_mean.transform(data)))
#
# TypeError: to_hdf() missing 2 required positional arguments: 'path_or_buf' and 'key'

# %%
data.head(n=100)
# Out:
#            Date  WSR0  WSR1  WSR2  WSR3  WSR4  WSR5  WSR6  WSR7  WSR8  ...  \
# 1/1/1998    0.8   1.8   2.4   2.1   2.0   2.1   1.5   1.7   1.9   2.3  ...
# 1/2/1998    2.8   3.2   3.3   2.7   3.3   3.2   2.9   2.8   3.1   3.4  ...
# 1/3/1998    2.9   2.8   2.6   2.1   2.2   2.5   2.5   2.7   2.2   2.5  ...
# 1/4/1998    4.7   3.8   3.7   3.8   2.9   3.1   2.8   2.5   2.4   3.1  ...
# 1/5/1998    2.6   2.1   1.6   1.4   0.9   1.5   1.2   1.4   1.3   1.4  ...
# ...         ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 4/6/1998    0.4   0.4   0.4   0.1   0.8   1.3   1.4   1.7   2.7   4.0  ...
# 4/7/1998    0.4   0.8   1.8   1.9   1.0   0.9   1.7   2.3   2.2   3.4  ...
# 4/8/1998    2.5   1.4   2.6   2.9   1.9   1.4   1.7   1.8   0.4   1.8  ...
# 4/9/1998    2.3   1.3   0.3   0.5   0.4   0.5   0.5   2.1   3.1   3.8  ...
# 4/10/1998   0.1   0.4   0.6   0.4   1.0   1.7   0.7   1.3   2.3   2.4  ...
#
# ...
